# %% [markdown]
# #### Model Training

# %%
import pandas as pd
data_set=pd.read_csv('./data/gemstone.csv')

# %%
data_set.head(10)
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453
# 5   5   1.51  Very Good     J     SI1   62.8   58.0  7.34  7.29  4.59   7506
# 6   6   0.74      Ideal     E     VS2   61.8   57.0  5.76  5.79  3.57   3229
# 7   7   1.34    Premium     G     SI2   62.5   57.0  7.00  7.05  4.38   6224
# 8   8   0.30      Ideal     F      IF   62.0   56.0  4.35  4.37  2.70    886
# 9   9   0.30       Good     J     VS1   63.6   57.0  4.26  4.28  2.72    421

# %%
data_set=data_set.drop(labels=['id'],axis=1)

# %%
# Independent and dependent features 
X=data_set.drop(labels=['price'],axis=1)
y=data_set[['price']] # Here double bracket is applied for getting the coloumn name and data.

# %%
X.head(10)
# Out:
#    carat        cut color clarity  depth  table     x     y     z
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77
# 5   1.51  Very Good     J     SI1   62.8   58.0  7.34  7.29  4.59
# 6   0.74      Ideal     E     VS2   61.8   57.0  5.76  5.79  3.57
# 7   1.34    Premium     G     SI2   62.5   57.0  7.00  7.05  4.38
# 8   0.30      Ideal     F      IF   62.0   56.0  4.35  4.37  2.70
# 9   0.30       Good     J     VS1   63.6   57.0  4.26  4.28  2.72

# %%
y.head(10)
# Out:
#    price
# 0  13619
# 1  13387
# 2   2772
# 3    666
# 4  14453
# 5   7506
# 6   3229
# 7   6224
# 8    886
# 9    421

# %%
# CAtegorial and ordinal data set diviion of the independent variable.

# %%
categorical_columns= X.select_dtypes(include='object').columns
numericals_columns=X.select_dtypes(exclude='object').columns

# %%
categorical_columns
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
numericals_columns
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')

# %%
cut_ranking = ['Fair','Good','Very Good','Premium','Ideal']
color_ranking = ['D','E','F','G','H','I','J']
clarity_ranking = ['SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF']

# %% [markdown]
# ## sklearn.impute - Machine Learning Technique to handle the missing values. ## StandardScaler - ML Tech for Feature Scaling (Z-Score)

# %%
from sklearn.impute import SimpleImputer # Used for Handing Missing Values
from sklearn.preprocessing import StandardScaler # Used for Feature Scaling.(Z-Score)
from sklearn.preprocessing import OrdinalEncoder # Used for Ranking the Categorial Data.
# All these Data convertion has to be done in order . Therefore Pipeline is Important
from sklearn.pipeline import Pipeline 
from sklearn.compose import ColumnTransformer # All These need to be in Group. This is the Workflow.

# %%
# Numerical pipeline
num_pipeline=Pipeline(
    steps=[('Imputer',SimpleImputer(strategy='median')),
    ('FScaler',StandardScaler())
    ]
)
# Categorical Pipeline 
cat_pipeline=Pipeline(steps=
    [
    ('Imputer',SimpleImputer(strategy='most_frequent')),
    ('OrdinalEnco',OrdinalEncoder(categories=[cut_ranking,color_ranking,clarity_ranking])),
    ('FScaler',StandardScaler())
    ]
)

# %%
num_pipeline
# Out:
# Pipeline(steps=[('Imputer', SimpleImputer(strategy='median')),
#                 ('FScaler', StandardScaler())])

# %%
cat_pipeline
# Out:
# Pipeline(steps=[('Imputer', SimpleImputer(strategy='most_frequent')),
#                 ('OrdinalEnco',
#                  OrdinalEncoder(categories=[['Fair', 'Good', 'Very Good',
#                                              'Premium', 'Ideal'],
#                                             ['D', 'E', 'F', 'G', 'H', 'I', 'J'],
#                                             ['SI2', 'SI1', 'VS2', 'VS1', 'VVS2',
#                                              'VVS1', 'IF']])),
#                 ('FScaler', StandardScaler())])

# %%
preprocessor=ColumnTransformer([
    ('num_pipeline',num_pipeline,numericals_columns),
    ('cat_pipeline',cat_pipeline,categorical_columns)
])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('num_pipeline',
#                                  Pipeline(steps=[('Imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('FScaler',
#                                                   StandardScaler())]),
#                                  Index(['carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')),
#                                 ('cat_pipeline',
#                                  Pipeline(steps=[('Imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('OrdinalEnco',
#                                                   OrdinalEncoder(categories=[['Fair',
#                                                                               'Good',
#                                                                               'Very '
#                                                                               'Good',
#                                                                               'Premium',
#                                                                               'Ideal'],
#                                                                              ['D',
#                                                                               'E',
#                                                                               'F',
#                                                                               'G',
#                                                                               'H',
#                                                                               'I',
#                                                                               'J'],
#                                                                              ['SI2',
#                                                                               'SI1',
#                                                                               'VS2',
#                                                                               'VS1',
#                                                                               'VVS2',
#                                                                               'VVS1',
#                                                                               'IF']])),
#                                                  ('FScaler',
#                                                   StandardScaler())]),
#                                  Index(['cut', 'color', 'clarity'], dtype='object'))])

# %% [markdown]
# #### Now its time for Train Test Split.

# %%
from sklearn.model_selection import train_test_split # Libraries Imported.
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,shuffle=True,random_state=42)

# %%
pd.DataFrame(preprocessor.fit_transform(y_train),columns=preprocessor.get_feature_names_out())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Education\Full Stack Data Science Boot Camp 2.0\End_To_End_Project\Diamond_Price_Prediction\venv\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File d:\Education\Full Stack Data Science Boot Camp 2.0\End_To_End_Project\Diamond_Price_Prediction\venv\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File d:\Education\Full Stack Data Science Boot Camp 2.0\End_To_End_Project\Diamond_Price_Prediction\venv\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'carat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File d:\Education\Full Stack Data Science Boot Camp 2.0\End_To_End_Project\Diamond_Price_Prediction\venv\lib\site-packages\sklearn\utils\__init__.py:448, in _get_column_indices(X, key)
#     447 for col in columns:
# --> 448     col_idx = all_columns.get_loc(col)
#     449     if not isinstance(col_idx, numbers.Integral):
#
# File d:\Education\Full Stack Data Science Boot Camp 2.0\End_To_End_Project\Diamond_Price_Prediction\venv\lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#
# KeyError: 'carat'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 pd.DataFrame(preprocessor.fit_transform(y_train),columns=preprocessor.get_feature_names_out())
#
# File d:\Education\Full Stack Data Science Boot Camp 2.0\End_To_End_Project\Diamond_Price_Prediction\venv\lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File d:\Education\Full Stack Data Science Boot Camp 2.0\End_To_End_Project\Diamond_Price_Prediction\venv\lib\site-packages\sklearn\compose\_column_transformer.py:724, in ColumnTransformer.fit_transform(self, X, y)
#     722 self._check_n_features(X, reset=True)
#     723 self._validate_transformers()
# --> 724 self._validate_column_callables(X)
#     725 self._validate_remainder(X)
#     727 result = self._fit_transform(X, y, _fit_transform_one)
#
# File d:\Education\Full Stack Data Science Boot Camp 2.0\End_To_End_Project\Diamond_Price_Prediction\venv\lib\site-packages\sklearn\compose\_column_transformer.py:426, in ColumnTransformer._validate_column_callables(self, X)
#     424         columns = columns(X)
#     425     all_columns.append(columns)
# --> 426     transformer_to_input_indices[name] = _get_column_indices(X, columns)
#     428 self._columns = all_columns
#     429 self._transformer_to_input_indices = transformer_to_input_indices
#
# File d:\Education\Full Stack Data Science Boot Camp 2.0\End_To_End_Project\Diamond_Price_Prediction\venv\lib\site-packages\sklearn\utils\__init__.py:456, in _get_column_indices(X, key)
#     453             column_indices.append(col_idx)
#     455     except KeyError as e:
# --> 456         raise ValueError("A given column is not a column of the dataframe") from e
#     458     return column_indices
#     459 else:
#
# ValueError: A given column is not a column of the dataframe
